# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sanji\anaconda3\lib\site-packages)
# ...

# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\sanji\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\sanji\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
import spotipy
from spotipy import SpotifyClientCredentials

# %%
client_credential_manager = SpotifyClientCredentials(client_id='f0799f5e463c4f02a1d001a724057717', 
                                                     client_secret='630b6ad0005d4449aa0c98a678db679e')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credential_manager)

# %%
# Bollywood Happy Songs
playlist_link = 'https://open.spotify.com/playlist/1tTXdi6Bp04Pgmam9bSN7W'

# %%
# My_Playlist#7
my_playlist = 'https://open.spotify.com/playlist/799Oyux2M6UCzMdGIcVI71'

# %%
my_playlist_URI = my_playlist.split('/')[-1]
my_playlist_URI
# Out:
# '799Oyux2M6UCzMdGIcVI71'

# %%
data = sp.playlist_tracks(my_playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/799Oyux2M6UCzMdGIcVI71/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-07-23T03:35:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/s4b2zcicyvh86jsaw6g25zigy'},
#     'href': 'https://api.spotify.com/v1/users/s4b2zcicyvh86jsaw6g25zigy',
#     'id': 's4b2zcicyvh86jsaw6g25zigy',
#     'type': 'user',
#     'uri': 'spotify:user:s4b2zcicyvh86jsaw6g25zigy'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
# ...

# %%
len(data['items'])
# Out:
# 52

# %%
data['items']
# Out:
# [{'added_at': '2025-07-23T03:35:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/s4b2zcicyvh86jsaw6g25zigy'},
#    'href': 'https://api.spotify.com/v1/users/s4b2zcicyvh86jsaw6g25zigy',
#    'id': 's4b2zcicyvh86jsaw6g25zigy',
#    'type': 'user',
#    'uri': 'spotify:user:s4b2zcicyvh86jsaw6g25zigy'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
from datetime import datetime

# %%
str(datetime.now())format('yyyy_mm_dd')
# Out:
# '2025-07-26 21:48:46.646300'

# %%
datetime.now().strftime('%Y%m%d%H%M%S')
# Out:
# '20250726215139'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6S8X2sG1FZ3xHWmrpdgFcG'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Hoodie'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-03-07'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6S8X2sG1FZ3xHWmrpdgFcG'

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    #print(album_name, ': total_track', album_total_tracks, ',url: ', album_url)
    album_element = {'album_id': album_id, 'name': album_name, 'release_date': album_release_date,
                 'total_tracks': album_total_tracks, 'url': album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6S8X2sG1FZ3xHWmrpdgFcG',
#   'name': 'Hoodie',
#   'release_date': '2024-03-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6S8X2sG1FZ3xHWmrpdgFcG'},
#  {'album_id': '3m5FIubiCHr9mH3BU7ngY4',
#   'name': 'Bhaag Milkha Bhaag (Original Motion Picture Soundtrack)',
#   'release_date': '2013-06-14',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/3m5FIubiCHr9mH3BU7ngY4'},
#  {'album_id': '1dbC4FvTy7dbDEZgWZEyh0',
#   'name': 'Kar Har Maidaan Fateh (From "Sanju")',
#   'release_date': '2018-06-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1dbC4FvTy7dbDEZgWZEyh0'},
#  {'album_id': '2HbE8iLZ27q5sAmSNib6jL',
#   'name': 'Get Ready To Fight',
#   'release_date': '2016-04-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2HbE8iLZ27q5sAmSNib6jL'},
#  {'album_id': '3m5FIubiCHr9mH3BU7ngY4',
#   'name': 'Bhaag Milkha Bhaag (Original Motion Picture Soundtrack)',
#   'release_date': '2013-06-14',
# ...

# %% [markdown]
# #### get artists info

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19MVxKZZdPj2X0F8pi0OCT'},
#   'href': 'https://api.spotify.com/v1/artists/19MVxKZZdPj2X0F8pi0OCT',
#   'id': '19MVxKZZdPj2X0F8pi0OCT',
#   'name': 'Sukhwinder Singh',
#   'type': 'artist',
#   'uri': 'spotify:artist:19MVxKZZdPj2X0F8pi0OCT'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy'},
#   'href': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy',
#   'id': '0oOet2f43PA68X5RxKobEy',
#   'name': 'Shreya Ghoshal',
#   'type': 'artist',
#   'uri': 'spotify:artist:0oOet2f43PA68X5RxKobEy'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0aXLGxJ65wok0y1bVG6flg'},
#   'href': 'https://api.spotify.com/v1/artists/0aXLGxJ65wok0y1bVG6flg',
#   'id': '0aXLGxJ65wok0y1bVG6flg',
#   'name': 'Vikram Montrose',
#   'type': 'artist',
#   'uri': 'spotify:artist:0aXLGxJ65wok0y1bVG6flg'}]

# %%
artist_list = []

for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artists = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artists)

# %%
#for row in data['items']:
#    for artist in row['track']['artists']:
#        print(artist)
#        #print(artist['id'], artist['name'], artist['external_urls']['spotify'])

# %%
artist_list
# Out:
# [{'artist_id': '1dqPqXbxxYtCtLbKeAN2Ss',
#   'artist_name': 'Akull',
#   'external_url': 'https://api.spotify.com/v1/artists/1dqPqXbxxYtCtLbKeAN2Ss'},
#  {'artist_id': '26ks59eSno7UlPCdljHQoI',
#   'artist_name': 'Shirley Setia',
#   'external_url': 'https://api.spotify.com/v1/artists/26ks59eSno7UlPCdljHQoI'},
#  {'artist_id': '0L5GV6LN8SWWUWIdBbTLTZ',
#   'artist_name': 'Shankar-Ehsaan-Loy',
#   'external_url': 'https://api.spotify.com/v1/artists/0L5GV6LN8SWWUWIdBbTLTZ'},
#  {'artist_id': '7hwEGO7U6JwQ7M1teoO8GW',
#   'artist_name': 'Siddharth Mahadevan',
#   'external_url': 'https://api.spotify.com/v1/artists/7hwEGO7U6JwQ7M1teoO8GW'},
#  {'artist_id': '19MVxKZZdPj2X0F8pi0OCT',
#   'artist_name': 'Sukhwinder Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/19MVxKZZdPj2X0F8pi0OCT'},
#  {'artist_id': '0oOet2f43PA68X5RxKobEy',
#   'artist_name': 'Shreya Ghoshal',
#   'external_url': 'https://api.spotify.com/v1/artists/0oOet2f43PA68X5RxKobEy'},
# ...

# %% [markdown]
# #### get Song info

# %%
song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    
    song_element = {'song_id': song_id, 'song_name': song_name, 'durations_ms': song_duration
                   , 'url': song_url, 'pupularity': song_popularity, 'song_added': song_added
                   , 'album_id': album_id, 'artist_id': artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '3hJ5fEOXMPqxpU6mdHFQCY',
#   'song_name': 'Hoodie',
#   'durations_ms': 187800,
#   'url': 'https://open.spotify.com/track/3hJ5fEOXMPqxpU6mdHFQCY',
#   'pupularity': 27,
#   'song_added': '2025-07-23T03:35:37Z',
#   'album_id': '6S8X2sG1FZ3xHWmrpdgFcG',
#   'artist_id': '1dqPqXbxxYtCtLbKeAN2Ss'},
#  {'song_id': '0KtHnXQjYkHNDsjTX3XqLc',
#   'song_name': 'Bhaag Milkha Bhaag - Rock Version',
#   'durations_ms': 279546,
#   'url': 'https://open.spotify.com/track/0KtHnXQjYkHNDsjTX3XqLc',
#   'pupularity': 63,
#   'song_added': '2025-07-23T03:35:39Z',
#   'album_id': '3m5FIubiCHr9mH3BU7ngY4',
#   'artist_id': '0L5GV6LN8SWWUWIdBbTLTZ'},
#  {'song_id': '3FHl1QYu76zguwjqhqcglX',
#   'song_name': 'Kar Har Maidaan Fateh (From "Sanju")',
#   'durations_ms': 312157,
#   'url': 'https://open.spotify.com/track/3FHl1QYu76zguwjqhqcglX',
#   'pupularity': 64,
#   'song_added': '2025-07-23T03:35:43Z',
#   'album_id': '1dbC4FvTy7dbDEZgWZEyh0',
#   'artist_id': '19MVxKZZdPj2X0F8pi0OCT'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  6S8X2sG1FZ3xHWmrpdgFcG                                             Hoodie
# 1  3m5FIubiCHr9mH3BU7ngY4  Bhaag Milkha Bhaag (Original Motion Picture So...
# 2  1dbC4FvTy7dbDEZgWZEyh0               Kar Har Maidaan Fateh (From "Sanju")
# 3  2HbE8iLZ27q5sAmSNib6jL                                 Get Ready To Fight
# 4  3m5FIubiCHr9mH3BU7ngY4  Bhaag Milkha Bhaag (Original Motion Picture So...
#
#   release_date  total_tracks  \
# 0   2024-03-07             1
# 1   2013-06-14             8
# 2   2018-06-10             1
# 3   2016-04-22             1
# 4   2013-06-14             8
#
#                                                  url
# 0  https://open.spotify.com/album/6S8X2sG1FZ3xHWm...
# 1  https://open.spotify.com/album/3m5FIubiCHr9mH3...
# 2  https://open.spotify.com/album/1dbC4FvTy7dbDEZ...
# 3  https://open.spotify.com/album/2HbE8iLZ27q5sAm...
# 4  https://open.spotify.com/album/3m5FIubiCHr9mH3...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      52 non-null     object
#  1   name          52 non-null     object
#  2   release_date  52 non-null     object
#  3   total_tracks  52 non-null     int64
#  4   url           52 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      49 non-null     object
#  1   name          49 non-null     object
#  2   release_date  49 non-null     object
#  3   total_tracks  49 non-null     int64
#  4   url           49 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.3+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\sanji\AppData\Local\Temp/ipykernel_7528/3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      49 non-null     object
#  1   name          49 non-null     object
#  2   release_date  49 non-null     datetime64[ns]
#  3   total_tracks  49 non-null     int64
#  4   url           49 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
artist_df.head()
# Out:
#                 artist_id          artist_name  \
# 0  1dqPqXbxxYtCtLbKeAN2Ss                Akull
# 1  26ks59eSno7UlPCdljHQoI        Shirley Setia
# 2  0L5GV6LN8SWWUWIdBbTLTZ   Shankar-Ehsaan-Loy
# 3  7hwEGO7U6JwQ7M1teoO8GW  Siddharth Mahadevan
# 4  19MVxKZZdPj2X0F8pi0OCT     Sukhwinder Singh
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1dqPqXbxxYt...
# 1  https://api.spotify.com/v1/artists/26ks59eSno7...
# 2  https://api.spotify.com/v1/artists/0L5GV6LN8SW...
# 3  https://api.spotify.com/v1/artists/7hwEGO7U6Jw...
# 4  https://api.spotify.com/v1/artists/19MVxKZZdPj...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     116 non-null    object
#  1   artist_name   116 non-null    object
#  2   external_url  116 non-null    object
# dtypes: object(3)
# memory usage: 2.8+ KB

# %%
artist_df = artist_df.drop_duplicates(subset='artist_id')

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 114
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     91 non-null     object
#  1   artist_name   91 non-null     object
#  2   external_url  91 non-null     object
# dtypes: object(3)
# memory usage: 2.8+ KB

# %%
song_df.head()
# Out:
#                   song_id                             song_name  durations_ms  \
# 0  3hJ5fEOXMPqxpU6mdHFQCY                                Hoodie        187800
# 1  0KtHnXQjYkHNDsjTX3XqLc     Bhaag Milkha Bhaag - Rock Version        279546
# 2  3FHl1QYu76zguwjqhqcglX  Kar Har Maidaan Fateh (From "Sanju")        312157
# 3  3n1IbkZGIxwP27kiE3TKtP                    Get Ready To Fight        204741
# 4  6cUM4yawhVYPXArGp6eWJe                    Bhaag Milkha Bhaag        269840
#
#                                                  url  pupularity  \
# 0  https://open.spotify.com/track/3hJ5fEOXMPqxpU6...          27
# 1  https://open.spotify.com/track/0KtHnXQjYkHNDsj...          63
# 2  https://open.spotify.com/track/3FHl1QYu76zguwj...          64
# 3  https://open.spotify.com/track/3n1IbkZGIxwP27k...          61
# 4  https://open.spotify.com/track/6cUM4yawhVYPXAr...          59
#
#              song_added                album_id               artist_id
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_id       52 non-null     object
#  1   song_name     52 non-null     object
#  2   durations_ms  52 non-null     int64
#  3   url           52 non-null     object
#  4   pupularity    52 non-null     int64
#  5   song_added    52 non-null     object
#  6   album_id      52 non-null     object
#  7   artist_id     52 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.4+ KB

# %%
song_df = song_df.drop_duplicates(subset='song_id')

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_id       52 non-null     object
#  1   song_name     52 non-null     object
#  2   durations_ms  52 non-null     int64
#  3   url           52 non-null     object
#  4   pupularity    52 non-null     int64
#  5   song_added    52 non-null     object
#  6   album_id      52 non-null     object
#  7   artist_id     52 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.4+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   song_id       52 non-null     object
#  1   song_name     52 non-null     object
#  2   durations_ms  52 non-null     int64
#  3   url           52 non-null     object
#  4   pupularity    52 non-null     int64
#  5   song_added    52 non-null     datetime64[ns, UTC]
#  6   album_id      52 non-null     object
#  7   artist_id     52 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.4+ KB
